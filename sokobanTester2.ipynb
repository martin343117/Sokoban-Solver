# %%
import glob
import time

from sokoban import Warehouse
from mySokobanSolver import *
#Import the mySokobanSolver.py file to import all functions

def test_warehouse(problem_file, macro = False):
    '''
    This function will test the performance of your warehouse for either macro or elem solutions and return the result.
    You can check if this solution works with your gui, or by cleverly using the check_action_seq function.
    '''
    wh = Warehouse()
    wh.load_warehouse(problem_file)
    print(wh.__str__())
    print(taboo_cells(wh))
    print()
    print()
    # 'Right','Down','Left','Up'
    # print(check_action_seq(wh, ['Down','Left','Up','Right','Right','Right','Down','Left','Up', 'Left',
    #                             'Left','Down','Down','Right','Up','Left','Up','Right','Up', 'Up', 'Left',
    #                             'Down','Right','Down','Down','Right','Right','Up','Left','Down','Left','Up', 'Up']))


    student_answer = solve_sokoban_macro(wh)
    # student_answer = solve_sokoban_elem(wh)
    print(student_answer)
    
    return
#.............................................................

# problem_file="warehouses/warehouse_0035.txt"
problem_file="warehouses/warehouse_0093.txt"
print(f'Testing {problem_file}')
s = time.time()
print(problem_file)
print("Amount of graph iterations: ")
test_warehouse(problem_file)
# Out:
# Testing warehouses/warehouse_0093.txt
# warehouses/warehouse_0093.txt
# Amount of graph iterations
#  #########
# ##   #   ##
# #    #    #
# #  $ # $  #
# #   *.*   #
# ####.@.####
# #   *.*   #
# #  $ # $  #
# #    #    #
# ##   #   ##
#  #########
#  #########
# ##XXX#XXX##
# #X   #   X#
# #X   #   X#
# #X       X#
# ####   ####
# #X       X#
# #X   #   X#
# #X   #   X#
# ##XXX#XXX##
#  #########
#
#
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
